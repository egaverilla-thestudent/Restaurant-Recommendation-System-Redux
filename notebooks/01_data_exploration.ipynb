# %% [markdown]
# Business Dataset

# %%
import pandas as pd

business = pd.read_json(
    "/Users/edgardomosesezekielaverilla/Restaurant-Recommendation-System-Redux/yelp_dataset/yelp_academic_dataset_business.json",
    lines=True
)

# %%
business.head(3)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
#
# ...

# %%
business.shape
# Out:
# (150346, 14)

# %%
business.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150346 entries, 0 to 150345
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150346 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  float64
#  7   longitude     150346 non-null  float64
#  8   stars         150346 non-null  float64
#  9   review_count  150346 non-null  int64
#  10  is_open       150346 non-null  int64
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 16.1+ MB

# %%
business.describe()
# Out:
#             latitude      longitude          stars   review_count  \
# count  150346.000000  150346.000000  150346.000000  150346.000000
# mean       36.671150     -89.357339       3.596724      44.866561
# std         5.872759      14.918502       0.974421     121.120136
# min        27.555127    -120.095137       1.000000       5.000000
# 25%        32.187293     -90.357810       3.000000       8.000000
# 50%        38.777413     -86.121179       3.500000      15.000000
# 75%        39.954036     -75.421542       4.500000      37.000000
# max        53.679197     -73.200457       5.000000    7568.000000
#
#             is_open
# count  150346.00000
# mean        0.79615
# std         0.40286
# min         0.00000
# 25%         1.00000
# 50%         1.00000
# 75%         1.00000
# max         1.00000

# %%
business.isnull().sum()
# Out:
# business_id         0
# name                0
# address             0
# city                0
# state               0
# postal_code         0
# latitude            0
# longitude           0
# stars               0
# review_count        0
# is_open             0
# attributes      13744
# categories        103
# hours           23223
# dtype: int64

# %% [markdown]
# User Dataset

# %%
user = pd.read_json("/Users/edgardomosesezekielaverilla/Restaurant-Recommendation-System-Redux/yelp_dataset/yelp_academic_dataset_user.json", lines = True, nrows=10000)

# %%
user.head(3)
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# 1  ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138  ...
# 2  LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52  ...
#
#    compliment_more  compliment_profile  compliment_cute  compliment_list  \
# ...

# %%
user.shape
# Out:
# (10000, 22)

# %%
user.columns
# Out:
# Index(['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny',
#        'cool', 'elite', 'friends', 'fans', 'average_stars', 'compliment_hot',
#        'compliment_more', 'compliment_profile', 'compliment_cute',
#        'compliment_list', 'compliment_note', 'compliment_plain',
#        'compliment_cool', 'compliment_funny', 'compliment_writer',
#        'compliment_photos'],
#       dtype='object')

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             10000 non-null  object
#  1   name                10000 non-null  object
#  2   review_count        10000 non-null  int64
#  3   yelping_since       10000 non-null  object
#  4   useful              10000 non-null  int64
#  5   funny               10000 non-null  int64
#  6   cool                10000 non-null  int64
#  7   elite               10000 non-null  object
#  8   friends             10000 non-null  object
#  9   fans                10000 non-null  int64
#  10  average_stars       10000 non-null  float64
#  11  compliment_hot      10000 non-null  int64
#  12  compliment_more     10000 non-null  int64
#  13  compliment_profile  10000 non-null  int64
#  14  compliment_cute     10000 non-null  int64
# ...

# %%
user.describe()
# Out:
#        review_count         useful         funny           cool          fans  \
# count   10000.00000   10000.000000  10000.000000   10000.000000  10000.000000
# mean      278.61810     911.666300    465.440600     606.360300     32.559700
# std       502.63081    3695.356472   2292.975591    3071.287502    162.946065
# min         1.00000       0.000000      0.000000       0.000000      0.000000
# 25%        34.75000      45.750000     10.000000      14.000000      2.000000
# 50%       115.00000     176.000000     55.000000      68.000000      7.000000
# 75%       323.00000     628.000000    239.000000     299.000000     25.000000
# max     16567.00000  173089.000000  98459.000000  144849.000000  12497.000000
#
#        average_stars  compliment_hot  compliment_more  compliment_profile  \
# count   10000.000000    10000.000000     10000.000000        10000.000000
# mean        3.832046       60.317000         8.324200            6.862600
# ...

# %%
user.isnull().sum()
# Out:
# user_id               0
# name                  0
# review_count          0
# yelping_since         0
# useful                0
# funny                 0
# cool                  0
# elite                 0
# friends               0
# fans                  0
# average_stars         0
# compliment_hot        0
# compliment_more       0
# compliment_profile    0
# compliment_cute       0
# compliment_list       0
# compliment_note       0
# compliment_plain      0
# compliment_cool       0
# compliment_funny      0
# compliment_writer     0
# compliment_photos     0
# dtype: int64

# %% [markdown]
# Review Dataset

# %%
review = pd.read_json("/Users/edgardomosesezekielaverilla/Restaurant-Recommendation-System-Redux/yelp_dataset/yelp_academic_dataset_review.json", lines = True, nrows = 100000)

review.head(3)
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30

# %%
review.shape
# Out:
# (100000, 9)

# %%
review.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars', 'useful', 'funny',
#        'cool', 'text', 'date'],
#       dtype='object')

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   review_id    100000 non-null  object
#  1   user_id      100000 non-null  object
#  2   business_id  100000 non-null  object
#  3   stars        100000 non-null  int64
#  4   useful       100000 non-null  int64
#  5   funny        100000 non-null  int64
#  6   cool         100000 non-null  int64
#  7   text         100000 non-null  object
#  8   date         100000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 6.9+ MB

# %%
review.describe()
# Out:
#                stars         useful          funny           cool  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        3.842910       0.898980       0.257180       0.347030
# min         1.000000       0.000000       0.000000       0.000000
# 25%         3.000000       0.000000       0.000000       0.000000
# 50%         4.000000       0.000000       0.000000       0.000000
# 75%         5.000000       1.000000       0.000000       0.000000
# max         5.000000     320.000000      98.000000      49.000000
# std         1.354729       2.205186       1.010212       1.066382
#
#                                 date
# count                         100000
# mean   2015-05-02 14:36:08.625299968
# min              2005-03-01 17:47:15
# 25%    2013-12-07 13:33:34.750000128
# 50%       2015-09-26 23:21:59.500000
# 75%    2017-04-08 12:26:05.249999872
# max              2018-10-04 18:22:35
# std                              NaN

# %%
review.isnull().sum()
# Out:
# review_id      0
# user_id        0
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64

# %% [markdown]
# tip dataset

# %%
tip = pd.read_json("/Users/edgardomosesezekielaverilla/Restaurant-Recommendation-System-Redux/yelp_dataset/yelp_academic_dataset_tip.json", lines = True, nrows = 100000)

# %%
tip.head(3)
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
#
#                                                 text                date  \
# 0                     Avengers time with the ladies. 2012-05-18 02:17:21
# 1  They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# 2             It's open even when you think it isn't 2013-08-18 00:56:08
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0

# %%
tip.shape
# Out:
# (100000, 5)

# %%
tip.columns
# Out:
# Index(['user_id', 'business_id', 'text', 'date', 'compliment_count'], dtype='object')

# %%
tip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           100000 non-null  object
#  1   business_id       100000 non-null  object
#  2   text              100000 non-null  object
#  3   date              100000 non-null  datetime64[ns]
#  4   compliment_count  100000 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 3.8+ MB

# %%
tip.describe()
# Out:
#                                 date  compliment_count
# count                         100000     100000.000000
# mean   2014-01-16 23:24:28.094060032          0.013710
# min              2009-04-16 13:11:49          0.000000
# 25%              2012-04-29 01:56:45          0.000000
# 50%              2013-12-04 21:11:37          0.000000
# 75%              2015-09-10 21:16:18          0.000000
# max              2018-05-05 08:19:29          5.000000
# std                              NaN          0.124749

# %%
tip.isnull().sum()
# Out:
# user_id             0
# business_id         0
# text                0
# date                0
# compliment_count    0
# dtype: int64

# %% [markdown]
# checkin dataset

# %%
checkin = pd.read_json("/Users/edgardomosesezekielaverilla/Restaurant-Recommendation-System-Redux/yelp_dataset/yelp_academic_dataset_checkin.json", lines = True, nrows = 100000)

# %%
checkin.head(3)
# Out:
#               business_id                                               date
# 0  ---kPU91CF4Lq2-WlRu9Lw  2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1  --0iUa4sNDFiZFrAdIWhZQ  2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2  --30_8IhuyMHbSOcNWd6DQ           2013-06-14 23:29:17, 2014-08-13 23:20:22

# %%
checkin.shape
# Out:
# (100000, 2)

# %%
checkin.columns
# Out:
# Index(['business_id', 'date'], dtype='object')

# %%
checkin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   business_id  100000 non-null  object
#  1   date         100000 non-null  object
# dtypes: object(2)
# memory usage: 1.5+ MB

# %%
checkin.describe()
# Out:
#                    business_id  \
# count                   100000
# unique                  100000
# top     ---kPU91CF4Lq2-WlRu9Lw
# freq                         1
#
#                                                      date
# count                                              100000
# unique                                             100000
# top     2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# freq                                                    1

# %%
checkin.isnull().sum()
# Out:
# business_id    0
# date           0
# dtype: int64
