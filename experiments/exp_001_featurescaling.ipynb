# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler

restaurants = pd.read_csv("/Users/edgardomosesezekielaverilla/Restaurant-Recommendation-System-Redux/data/processed/restaurants_clean.csv")

taxonomy = pd.read_csv("/Users/edgardomosesezekielaverilla/Restaurant-Recommendation-System-Redux/data/reference/category_mapping.csv", encoding="cp1252")

restaurants.head(3)
# Out:
#               business_id                   name          city state  \
# 0  MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries  Philadelphia    PA
# 1  CF33F8-E6oudUQ46HnavjQ         Sonic Drive-In  Ashland City    TN
# 2  k0hlBqXX-Bt0vf1op7Jr1w  Tsevi's Pub And Grill        Affton    MO
#
#   postal_code   latitude  longitude  stars  review_count  \
# 0       19107  39.955505 -75.155564    4.0            80
# 1       37015  36.269593 -87.058943    2.0             6
# 2       63123  38.565165 -90.321087    3.0            19
#
#                                           categories  \
# 0  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 1  Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 2  Pubs, Restaurants, Italian, Bars, American (Tr...
#
#                                           attributes  \
# 0  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 1  {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 2  {'Caters': 'True', 'Alcohol': "u'full_bar'", '...
#
#                                                hours  is_open
# 0  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...        1
# 1  {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...        1
# 2                                             Uknown        0

# %%
continuous_features = restaurants[
    [
        "stars",
        "review_count"

    ]
]

scaler = StandardScaler()

scaled_numeric = scaler.fit_transform(continuous_features)

scaled_numeric_df = pd.DataFrame(scaled_numeric, columns = ['stars', 'review_count'])

scaled_numeric_df
# Out:
#           stars  review_count
# 0      0.584422     -0.038463
# 1     -1.826420     -0.430126
# 2     -0.620999     -0.361321
# 3     -2.429131     -0.408955
# 4      0.584422     -0.408955
# ...         ...           ...
# 52263 -0.620999     -0.403662
# 52264  0.584422     -0.287222
# 52265  1.187133     -0.276637
# 52266  1.187133     -0.387784
# 52267  1.187133     -0.366613
#
# [52268 rows x 2 columns]
