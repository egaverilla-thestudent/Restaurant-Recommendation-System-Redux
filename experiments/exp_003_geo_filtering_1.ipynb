# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

restaurants = pd.read_csv("/Users/edgardomosesezekielaverilla/Restaurant-Recommendation-System-Redux/data/processed/restaurants_clean.csv")

taxonomy = pd.read_csv("/Users/edgardomosesezekielaverilla/Restaurant-Recommendation-System-Redux/data/reference/category_mapping.csv", encoding="cp1252")

# %%
selected_restaurant = restaurants[
    restaurants["name"] == "Sonic Drive-In"
].iloc[0]

selected_restaurant
# Out:
# business_id                                CF33F8-E6oudUQ46HnavjQ
# name                                               Sonic Drive-In
# city                                                 Ashland City
# state                                                          TN
# postal_code                                                 37015
# latitude                                                36.269593
# longitude                                              -87.058943
# stars                                                         2.0
# review_count                                                    6
# categories      Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# attributes      {'BusinessParking': 'None', 'BusinessAcceptsCr...
# hours           {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# is_open                                                         1
# Name: 1, dtype: object

# %%
selected_state = selected_restaurant["state"]

print(selected_state)
# Out:
# TN

# %%
subset_restaurants = restaurants[
    restaurants["state"] == selected_state
].copy()

print(len(restaurants))
print(len(subset_restaurants))
# Out:
# 52268
# 4352

# %%
subset_restaurants["state"].value_counts()
# Out:
# state
# TN    4352
# Name: count, dtype: int64

# %%
subset_restaurants.head()
# Out:
#                business_id                name          city state  \
# 1   CF33F8-E6oudUQ46HnavjQ      Sonic Drive-In  Ashland City    TN
# 3   bBDDEgkFA1Otx9Lfe7BZUQ      Sonic Drive-In     Nashville    TN
# 12  4iRzR7OaS-QaSXuvYxEGKA           Super Dog     Nashville    TN
# 13  tMkwHmWFUEXrC9ZduonpTg  The Green Pheasant     Nashville    TN
# 15  sqSqqLy0sN8n2IZrAbzidQ      Domino's Pizza   White House    TN
#
#    postal_code   latitude  longitude  stars  review_count  \
# 1        37015  36.269593 -87.058943    2.0             6
# 3        37207  36.208102 -86.768170    1.5            10
# 12       37115  36.248570 -86.719986    4.0             6
# 13       37201  36.159886 -86.773197    4.0           161
# 15       37188  36.464747 -86.659187    3.5             8
#
#                                            categories  \
# 1   Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 3   Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 12                              Hot Dogs, Restaurants
# 13                     Restaurants, Japanese, Seafood
# 15      Pizza, Chicken Wings, Sandwiches, Restaurants
#
#                                            attributes  \
# 1   {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 3   {'RestaurantsAttire': "'casual'", 'Restaurants...
# 12  {'RestaurantsReservations': 'False', 'Restaura...
# 13  {'RestaurantsGoodForGroups': 'True', 'HappyHou...
# 15                    {'RestaurantsPriceRange2': '1'}
#
#                                                 hours  is_open
# 1   {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...        1
# 3   {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...        1
# 12                                             Uknown        0
# 13  {'Wednesday': '16:0-22:0', 'Thursday': '16:0-2...        0
# 15  {'Monday': '10:0-0:0', 'Tuesday': '10:0-0:0', ...        1

# %%
subset_restaurants.index
# Out:
# Index([    1,     3,    12,    13,    15,    22,    40,    49,    59,    60,
#        ...
#        52155, 52167, 52176, 52179, 52193, 52200, 52249, 52250, 52259, 52261],
#       dtype='int64', length=4352)

# %%
RangeIndex(start=0, stop=4352, step=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 RangeIndex(start=0, stop=4352, step=1)
#
# NameError: name 'RangeIndex' is not defined
